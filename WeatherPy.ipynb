# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 647

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
#print(url)

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in our list.
for i in range(len(cities)):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + cities[i]

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
       
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | rikitea
# Processing Record 2 of Set 1 | salekhard
# Processing Record 3 of Set 1 | college
# Processing Record 4 of Set 1 | inirida
# Processing Record 5 of Set 1 | jamestown
# Processing Record 6 of Set 1 | ushuaia
# Processing Record 7 of Set 1 | kapaa
# Processing Record 8 of Set 1 | lata
# Processing Record 9 of Set 1 | bay roberts
# Processing Record 10 of Set 1 | potosi
# Processing Record 11 of Set 1 | grand haven
# Processing Record 12 of Set 1 | qaanaaq
# Processing Record 13 of Set 1 | castro
# Processing Record 14 of Set 1 | winnemucca
# Processing Record 15 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 16 of Set 1 | caravelas
# Processing Record 17 of Set 1 | leczyca
# Processing Record 18 of Set 1 | phalodi
# Processing Record 19 of Set 1 | busselton
# Processing Record 20 of Set 1 | beringovskiy
# Processing Record 21 of Set 1 | bluff
# Processing Record 22 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 23 of Set 1 | nizhnevartovsk
# Processing Record 24 of Set 1 | hilo
# Processing Record 25 of Set 1 | mana
# Processing Record 26 of Set 1 | yellowknife
# Processing Record 27 of Set 1 | souillac
# Processing Record 28 of Set 1 | punta arenas
# Processing Record 29 of Set 1 | turayf
# Processing Record 30 of Set 1 | balabac
# Processing Record 31 of Set 1 | karaton
# Processing Record 32 of Set 1 | mataura
# Processing Record 33 of Set 1 | alyangula
# Processing Record 34 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 35 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 36 of Set 1 | barrow
# Processing Record 37 of Set 1 | ciudad bolivar
# Processing Record 38 of Set 1 | lebu
# Processing Record 39 of Set 1 | hambantota
# Processing Record 40 of Set 1 | hofn
# Processing Record 41 of Set 1 | viligili
# City not found. Skipping...
# Processing Record 42 of Set 1 | shalinskoye
# Processing Record 43 of Set 1 | faanui
# Processing Record 44 of Set 1 | hermanus
# Processing Record 45 of Set 1 | east london
# Processing Record 46 of Set 1 | chokurdakh
# Processing Record 47 of Set 1 | esperance
# Processing Record 48 of Set 1 | benguela
# Processing Record 49 of Set 1 | ribeira grande
# Processing Record 50 of Set 1 | cidreira
# Processing Record 1 of Set 2 | doha
# Processing Record 2 of Set 2 | lorengau
# Processing Record 3 of Set 2 | pangody
# Processing Record 21 of Set 3 | whitehorse
# Processing Record 22 of Set 3 | vao
# Processing Record 23 of Set 3 | pietersburg
# Processing Record 24 of Set 3 | khatanga
# Processing Record 25 of Set 3 | poum
# Processing Record 26 of Set 3 | pacifica
# Processing Record 27 of Set 3 | bredasdorp
# Processing Record 28 of Set 3 | port elizabeth
# Processing Record 29 of Set 3 | georgetown
# Processing Record 30 of Set 3 | kluczbork
# Processing Record 31 of Set 3 | gold coast
# Processing Record 32 of Set 3 | bambous virieux
# Processing Record 33 of Set 3 | mimoso do sul
# Processing Record 34 of Set 3 | las cruces
# Processing Record 35 of Set 3 | koch bihar
# Processing Record 36 of Set 3 | pacific grove
# Processing Record 37 of Set 3 | bengkulu
# Processing Record 38 of Set 3 | arraial do cabo
# Processing Record 39 of Set 3 | urucui
# Processing Record 40 of Set 3 | novyy nekouz
# Processing Record 41 of Set 3 | bridlington
# Processing Record 42 of Set 3 | manicore
# Processing Record 43 of Set 3 | saskylakh
# Processing Record 44 of Set 3 | kalengwa
# Processing Record 45 of Set 3 | tarauaca
# Processing Record 46 of Set 3 | makakilo city
# Processing Record 47 of Set 3 | praia da vitoria
# Processing Record 48 of Set 3 | mahajanga
# Processing Record 49 of Set 3 | juybar
# Processing Record 50 of Set 3 | rawson
# Processing Record 1 of Set 4 | lubyany
# Processing Record 2 of Set 4 | biloela
# Processing Record 3 of Set 4 | laguna
# Processing Record 4 of Set 4 | acara
# Processing Record 5 of Set 4 | thompson
# Processing Record 6 of Set 4 | byron bay
# Processing Record 7 of Set 4 | pochutla
# Processing Record 8 of Set 4 | kargasok
# Processing Record 9 of Set 4 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 10 of Set 4 | atagay
# Processing Record 11 of Set 4 | tabou
# Processing Record 12 of Set 4 | saveh
# Processing Record 13 of Set 4 | korla
# Processing Record 14 of Set 4 | hithadhoo
# Processing Record 15 of Set 4 | mahebourg
# Processing Record 16 of Set 4 | neiafu
# Processing Record 17 of Set 4 | karratha
# Processing Record 18 of Set 4 | haines junction
# Processing Record 19 of Set 4 | batticaloa
# Processing Record 20 of Set 4 | muzhi
# Processing Record 21 of Set 4 | manta
# Processing Record 22 of Set 4 | iqaluit
# Processing Record 23 of Set 4 | zabol
# Processing Record 24 of Set 4 | hutang
# Processing Record 25 of Set 4 | kilindoni
# Processing Record 26 of Set 4 | dalvik
# Processing Record 27 of Set 4 | kharp
# Processing Record 28 of Set 4 | hobyo
# Processing Record 29 of Set 4 | cam pha
# City not found. Skipping...
# Processing Record 30 of Set 4 | bethel
# Processing Record 31 of Set 4 | mar del plata
# Processing Record 32 of Set 4 | yining
# Processing Record 33 of Set 4 | geraldton
# Processing Record 34 of Set 4 | narsaq
# Processing Record 35 of Set 4 | norman wells
# Processing Record 36 of Set 4 | yulara
# Processing Record 37 of Set 4 | buraydah
# Processing Record 38 of Set 4 | fenyi
# Processing Record 39 of Set 4 | mamit
# Processing Record 40 of Set 4 | bilibino
# Processing Record 41 of Set 4 | cayenne
# Processing Record 42 of Set 4 | tasiilaq
# Processing Record 43 of Set 4 | vanimo
# Processing Record 44 of Set 4 | kununurra
# Processing Record 45 of Set 4 | simplicio mendes
# Processing Record 46 of Set 4 | dingle
# Processing Record 47 of Set 4 | akyab
# Processing Record 48 of Set 4 | cam ranh
# Processing Record 49 of Set 4 | ancud
# Processing Record 50 of Set 4 | santiago del estero
# Processing Record 1 of Set 5 | te anau
# Processing Record 2 of Set 5 | kaniama
# Processing Record 3 of Set 5 | zile
# Processing Record 4 of Set 5 | ternate
# Processing Record 5 of Set 5 | mahibadhoo
# Processing Record 6 of Set 5 | forestville
# Processing Record 7 of Set 5 | avarua
# Processing Record 8 of Set 5 | ukiah
# Processing Record 9 of Set 5 | mbandaka
# Processing Record 10 of Set 5 | tigil
# Processing Record 11 of Set 5 | flin flon
# Processing Record 12 of Set 5 | padang
# Processing Record 13 of Set 5 | los llanos de aridane
# Processing Record 14 of Set 5 | yomou
# Processing Record 15 of Set 5 | carnarvon
# Processing Record 16 of Set 5 | mandalgovi
# Processing Record 17 of Set 5 | christchurch
# Processing Record 18 of Set 5 | harper
# Processing Record 19 of Set 5 | barra patuca
# Processing Record 20 of Set 5 | ariquemes
# Processing Record 21 of Set 5 | baruun-urt
# Processing Record 22 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 23 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 24 of Set 5 | sitka
# Processing Record 25 of Set 5 | gao
# Processing Record 26 of Set 5 | yeletskiy
# City not found. Skipping...
# Processing Record 27 of Set 5 | gondar
# Processing Record 28 of Set 5 | kruisfontein
# Processing Record 29 of Set 5 | kahului
# Processing Record 30 of Set 5 | zhigansk
# Processing Record 31 of Set 5 | kieta
# Processing Record 32 of Set 5 | kapenguria
# Processing Record 33 of Set 5 | havelock
# Processing Record 34 of Set 5 | okitipupa
# Processing Record 35 of Set 5 | la ronge
# Processing Record 36 of Set 5 | fairbanks
# Processing Record 37 of Set 5 | collierville
# Processing Record 38 of Set 5 | port hardy
# Processing Record 39 of Set 5 | panlaitan
# Processing Record 40 of Set 5 | barra do corda
# Processing Record 41 of Set 5 | shenkursk
# Processing Record 42 of Set 5 | gat
# Processing Record 43 of Set 5 | burnie
# Processing Record 44 of Set 5 | yilan
# Processing Record 45 of Set 5 | evensk
# Processing Record 46 of Set 5 | vardo
# Processing Record 47 of Set 5 | jalu
# Processing Record 48 of Set 5 | dawson creek
# Processing Record 49 of Set 5 | qujing
# Processing Record 50 of Set 5 | vestmannaeyjar
# Processing Record 1 of Set 6 | ibra
# Processing Record 2 of Set 6 | alta floresta
# Processing Record 3 of Set 6 | matane
# Processing Record 4 of Set 6 | buta
# Processing Record 5 of Set 6 | cabo san lucas
# Processing Record 6 of Set 6 | grenada
# Processing Record 7 of Set 6 | impfondo
# Processing Record 8 of Set 6 | urdoma
# Processing Record 9 of Set 6 | yumen
# Processing Record 10 of Set 6 | kavaratti
# Processing Record 11 of Set 6 | enterprise
# Processing Record 12 of Set 6 | batagay-alyta
# Processing Record 13 of Set 6 | springhill
# Processing Record 14 of Set 6 | fare
# Processing Record 15 of Set 6 | westfield
# Processing Record 16 of Set 6 | bolotnoye
# Processing Record 17 of Set 6 | honningsvag
# Processing Record 18 of Set 6 | athabasca
# Processing Record 19 of Set 6 | dikson
# Processing Record 20 of Set 6 | port-cartier
# Processing Record 21 of Set 6 | rennes
# Processing Record 22 of Set 6 | simoes
# Processing Record 23 of Set 6 | riviere-au-renard
# Processing Record 24 of Set 6 | archidona
# Processing Record 25 of Set 6 | acapulco
# Processing Record 26 of Set 6 | nizhniy tsasuchey
# Processing Record 27 of Set 6 | bushehr
# Processing Record 28 of Set 6 | maniitsoq
# Processing Record 29 of Set 6 | port macquarie
# Processing Record 30 of Set 6 | dodge city
# Processing Record 31 of Set 6 | bijar
# Processing Record 32 of Set 6 | lembeni
# Processing Record 33 of Set 6 | tuktoyaktuk
# Processing Record 34 of Set 6 | aksarka
# Processing Record 35 of Set 6 | wasilla
# Processing Record 36 of Set 6 | vuktyl
# Processing Record 37 of Set 6 | butte
# Processing Record 38 of Set 6 | dunedin
# Processing Record 39 of Set 6 | guanay
# Processing Record 40 of Set 6 | salalah
# Processing Record 41 of Set 6 | katsuura
# Processing Record 42 of Set 6 | tarudant
# City not found. Skipping...
# Processing Record 43 of Set 6 | pangai
# Processing Record 44 of Set 6 | klyuchi
# Processing Record 45 of Set 6 | haibowan
# City not found. Skipping...
# Processing Record 46 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 47 of Set 6 | nanortalik
# Processing Record 48 of Set 6 | maragogi
# Processing Record 49 of Set 6 | katangli
# Processing Record 50 of Set 6 | opuwo
# Processing Record 1 of Set 7 | neryungri
# Processing Record 2 of Set 7 | grand gaube
# Processing Record 3 of Set 7 | wahran
# City not found. Skipping...
# Processing Record 4 of Set 7 | bonavista
# Processing Record 5 of Set 7 | eyl
# Processing Record 6 of Set 7 | srednekolymsk
# Processing Record 7 of Set 7 | malwan
# City not found. Skipping...
# Processing Record 8 of Set 7 | teya
# Processing Record 9 of Set 7 | emba
# Processing Record 10 of Set 7 | fountain hills
# Processing Record 11 of Set 7 | trairi
# Processing Record 12 of Set 7 | leningradskiy
# Processing Record 13 of Set 7 | hualmay
# Processing Record 14 of Set 7 | tuatapere
# Processing Record 15 of Set 7 | natal
# Processing Record 16 of Set 7 | ixtapa
# Processing Record 17 of Set 7 | freetown
# Processing Record 18 of Set 7 | palm beach
# Processing Record 19 of Set 7 | perevoz
# Processing Record 20 of Set 7 | boa vista
# Processing Record 21 of Set 7 | gushikawa
# Processing Record 22 of Set 7 | bafq
# Processing Record 23 of Set 7 | nantucket
# Processing Record 24 of Set 7 | beberibe
# Processing Record 25 of Set 7 | grindavik
# Processing Record 26 of Set 7 | kodiak
# Processing Record 27 of Set 7 | tabas
# Processing Record 28 of Set 7 | basco
# Processing Record 10 of Set 10 | abalak
# Processing Record 11 of Set 10 | chernyshevskiy
# Processing Record 12 of Set 10 | esmeraldas
# Processing Record 13 of Set 10 | quatre cocos
# Processing Record 14 of Set 10 | bereznik
# Processing Record 15 of Set 10 | kologriv
# Processing Record 16 of Set 10 | kenai
# Processing Record 17 of Set 10 | margate
# Processing Record 18 of Set 10 | calabozo
# Processing Record 19 of Set 10 | sumbe
# Processing Record 20 of Set 10 | visnes
# Processing Record 21 of Set 10 | tura
# Processing Record 22 of Set 10 | wajima
# Processing Record 23 of Set 10 | gamba
# Processing Record 24 of Set 10 | dzhusaly
# City not found. Skipping...
# Processing Record 25 of Set 10 | paita
# Processing Record 26 of Set 10 | airai
# Processing Record 27 of Set 10 | guane
# Processing Record 28 of Set 10 | nicoya
# Processing Record 29 of Set 10 | finnsnes
# Processing Record 30 of Set 10 | taltal
# Processing Record 31 of Set 10 | lienz
# Processing Record 32 of Set 10 | zyryanka
# Processing Record 33 of Set 10 | aquiraz
# Processing Record 34 of Set 10 | muros
# Processing Record 35 of Set 10 | taga
# Processing Record 36 of Set 10 | nalut
# Processing Record 37 of Set 10 | keflavik
# Processing Record 38 of Set 10 | mehran
# Processing Record 39 of Set 10 | khandagayty
# Processing Record 40 of Set 10 | adre
# Processing Record 41 of Set 10 | baisoara
# Processing Record 42 of Set 10 | fray bentos
# Processing Record 43 of Set 10 | bolshoy tsaryn
# City not found. Skipping...
# Processing Record 44 of Set 10 | praia
# Processing Record 45 of Set 10 | jiuquan
# Processing Record 46 of Set 10 | balakirevo
# Processing Record 47 of Set 10 | huangchuan
# Processing Record 48 of Set 10 | olafsvik
# Processing Record 49 of Set 10 | karwar
# Processing Record 50 of Set 10 | goshogawara
# Processing Record 1 of Set 11 | asau
# Processing Record 2 of Set 11 | bafata
# Processing Record 3 of Set 11 | comarapa
# Processing Record 4 of Set 11 | rocha
# Processing Record 5 of Set 11 | albstadt
# Processing Record 6 of Set 11 | ahipara
# Processing Record 7 of Set 11 | oskemen
# Processing Record 8 of Set 11 | quang ngai
# Processing Record 9 of Set 11 | umm lajj
# Processing Record 10 of Set 11 | krasnoselkup
# Processing Record 11 of Set 11 | takoradi
# Processing Record 12 of Set 11 | ust-kut
# Processing Record 13 of Set 11 | cedar rapids
# Processing Record 14 of Set 11 | abengourou
# Processing Record 15 of Set 11 | odweyne
# Processing Record 16 of Set 11 | codrington
# Processing Record 17 of Set 11 | comodoro rivadavia
# Processing Record 18 of Set 11 | salina cruz
# Processing Record 19 of Set 11 | derzhavinsk
# Processing Record 20 of Set 11 | ayaviri
# Processing Record 21 of Set 11 | lamar
# Processing Record 22 of Set 11 | samut prakan
# Processing Record 23 of Set 11 | wuning
# Processing Record 24 of Set 11 | abu jubayhah
# City not found. Skipping...
# Processing Record 25 of Set 11 | gornopravdinsk
# Processing Record 26 of Set 11 | shaoyang
# Processing Record 27 of Set 11 | hamilton
# Processing Record 28 of Set 11 | rokytne
# Processing Record 29 of Set 11 | anito
# Processing Record 30 of Set 11 | samalaeulu
# City not found. Skipping...
# Processing Record 31 of Set 11 | camocim
# Processing Record 32 of Set 11 | saldanha
# Processing Record 33 of Set 11 | morant bay
# Processing Record 34 of Set 11 | gol
# Processing Record 35 of Set 11 | rio gallegos
# Processing Record 36 of Set 11 | tokat
# Processing Record 37 of Set 11 | birjand
# Processing Record 38 of Set 11 | gravdal
# Processing Record 39 of Set 11 | columbus
# Processing Record 40 of Set 11 | vigrestad
# Processing Record 41 of Set 11 | port lincoln
# Processing Record 42 of Set 11 | qasigiannguit
# Processing Record 43 of Set 11 | coihueco
# Processing Record 44 of Set 11 | warqla
# City not found. Skipping...
# Processing Record 45 of Set 11 | kavieng
# Processing Record 46 of Set 11 | harlingen
# Processing Record 47 of Set 11 | sur
# Processing Record 48 of Set 11 | tucuman
# Processing Record 49 of Set 11 | pathein
# Processing Record 50 of Set 11 | homer
# Processing Record 1 of Set 12 | sucua
# Processing Record 2 of Set 12 | maryville
# Processing Record 3 of Set 12 | toledo
# Processing Record 4 of Set 12 | pareora
# Processing Record 5 of Set 12 | abu samrah
# Processing Record 6 of Set 12 | vilhena
# Processing Record 7 of Set 12 | baillif
# Processing Record 8 of Set 12 | divnomorskoye
# Processing Record 9 of Set 12 | artsyz
# Processing Record 10 of Set 12 | damme
# Processing Record 11 of Set 12 | kasongo
# Processing Record 12 of Set 12 | rungata
# City not found. Skipping...
# Processing Record 13 of Set 12 | hasaki
# Processing Record 14 of Set 12 | olinda
# Processing Record 15 of Set 12 | oistins
# Processing Record 16 of Set 12 | alotau
# City not found. Skipping...
# Processing Record 17 of Set 12 | honiara
# Processing Record 18 of Set 12 | tela
# Processing Record 19 of Set 12 | santa cruz
# Processing Record 20 of Set 12 | goalpara
# Processing Record 21 of Set 12 | ust-tsilma
# Processing Record 22 of Set 12 | oktyabrskiy
# Processing Record 23 of Set 12 | juneau
# Processing Record 24 of Set 12 | cascais
# Processing Record 25 of Set 12 | mehamn
# Processing Record 26 of Set 12 | sredec
# City not found. Skipping...
# Processing Record 27 of Set 12 | khormuj
# City not found. Skipping...
# Processing Record 28 of Set 12 | karaul
# City not found. Skipping...
# Processing Record 29 of Set 12 | tiarei
# Processing Record 30 of Set 12 | vastervik
# City not found. Skipping...
# Processing Record 31 of Set 12 | saint george
# Processing Record 32 of Set 12 | cap-aux-meules
# Processing Record 33 of Set 12 | maua
# Processing Record 34 of Set 12 | hermon
# Processing Record 35 of Set 12 | aklavik
# Processing Record 36 of Set 12 | ilhabela
# Processing Record 37 of Set 12 | suntar
# Processing Record 38 of Set 12 | novyy urengoy
# Processing Record 39 of Set 12 | cumberland
# Processing Record 40 of Set 12 | chinhoyi
# Processing Record 41 of Set 12 | varhaug
# Processing Record 42 of Set 12 | sawtell
# Processing Record 43 of Set 12 | divo
# Processing Record 44 of Set 12 | atikokan
# Processing Record 45 of Set 12 | akhmim
# Processing Record 46 of Set 12 | gunjur
# Processing Record 47 of Set 12 | woodstock
# Processing Record 48 of Set 12 | banjar
# Processing Record 49 of Set 12 | ulaangom
# Processing Record 50 of Set 12 | kirkuk
# Processing Record 1 of Set 13 | ha giang
# Processing Record 2 of Set 13 | sao gabriel da cachoeira
# Processing Record 3 of Set 13 | kuche
# City not found. Skipping...
# Processing Record 4 of Set 13 | nouadhibou
# Processing Record 5 of Set 13 | lima
# Processing Record 6 of Set 13 | arinos
# Processing Record 7 of Set 13 | beneditinos
# Processing Record 8 of Set 13 | toora-khem
# Processing Record 9 of Set 13 | road town
# Processing Record 10 of Set 13 | little current
# Processing Record 11 of Set 13 | manggar
# Processing Record 12 of Set 13 | marsh harbour
# Processing Record 13 of Set 13 | barawe
# City not found. Skipping...
# Processing Record 14 of Set 13 | karavayevo
# Processing Record 15 of Set 13 | port-gentil
# Processing Record 16 of Set 13 | inuvik
# Processing Record 17 of Set 13 | nyurba
# Processing Record 18 of Set 13 | fairlie
# Processing Record 19 of Set 13 | zhezkazgan
# Processing Record 20 of Set 13 | richards bay
# Processing Record 21 of Set 13 | beitbridge
# Processing Record 22 of Set 13 | conceicao da barra
# Processing Record 23 of Set 13 | san juan
# Processing Record 24 of Set 13 | umm durman
# City not found. Skipping...
# Processing Record 25 of Set 13 | svetlyy
# Processing Record 26 of Set 13 | aljezur
# Processing Record 27 of Set 13 | nishihara
# Processing Record 28 of Set 13 | berbera
# Processing Record 29 of Set 13 | tubruq
# City not found. Skipping...
# Processing Record 30 of Set 13 | sept-iles
# Processing Record 31 of Set 13 | ugoofaaru
# Processing Record 32 of Set 13 | stantsiya gorchakovo
# City not found. Skipping...
# Processing Record 33 of Set 13 | popondetta
# Processing Record 34 of Set 13 | yangjiang
# Processing Record 35 of Set 13 | churhat
# Processing Record 36 of Set 13 | magadan
# Processing Record 37 of Set 13 | kirakira
# Processing Record 38 of Set 13 | kanigoro
# Processing Record 39 of Set 13 | bitung
# Processing Record 40 of Set 13 | cozumel
# Processing Record 41 of Set 13 | makokou
# Processing Record 42 of Set 13 | tutoia
# Processing Record 43 of Set 13 | kovdor
# Processing Record 44 of Set 13 | procida
# Processing Record 45 of Set 13 | filadelfia
# Processing Record 46 of Set 13 | ankang
# Processing Record 47 of Set 13 | walvis bay
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0      Rikitea -23.1203 -134.9692     77.90        72           2       15.01
# 1    Salekhard  66.5300   66.6019      8.67        90          96        5.75
# 2      College  64.8569 -147.8028     25.12        41          75       10.36
# 3      Inirida   3.8653  -67.9239     77.59        82         100        3.22
# 4    Jamestown  42.0970  -79.2353     48.06        56          75       17.27
# 5      Ushuaia -54.8000  -68.3000     44.26        65          40       11.50
# 6        Kapaa  22.0752 -159.3190     76.98        85          75       14.97
# 7         Lata  40.1629   -8.3327     66.22        59          39        6.40
# 8  Bay Roberts  47.5999  -53.2648     58.75        59          51       14.94
# 9       Potosi -19.5836  -65.7531     60.64         9           1       16.93
#
#   Country                 Date
# 0      PF  2022-04-16 18:26:07
# 1      RU  2022-04-16 18:26:07
# 2      US  2022-04-16 18:26:07
# 3      CO  2022-04-16 18:26:07
# 4      US  2022-04-16 18:21:47
# 5      AR  2022-04-16 18:21:33
# 6      US  2022-04-16 18:26:08
# 7      PT  2022-04-16 18:26:08
# 8      CA  2022-04-16 18:26:08
# 9      BO  2022-04-16 18:26:09

# %%
#new_column_order = ["column2", "column4", "column1"]
#df = df[new_column_order]

# %%
# Create the output file (CSV).
output_data_file = "weather_data/cities.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")

# %%
# Extract relevant fields from the DataFrame for plotting.
lats = city_data_df["Lat"]
max_temps = city_data_df["Max Temp"]
humidity = city_data_df["Humidity"]
cloudiness = city_data_df["Cloudiness"]
wind_speed = city_data_df["Wind Speed"]

# %%
# Import the time module.
import time
# Get today's date in seconds.
today = time.time()
today
# Out:
# 1650138114.7962341

# %%
today = time.strftime("%x")
today
# Out:
# '04/16/22'

# %%
# Import time module
import time

# Build the scatter plot for latitude vs. max temperature.
plt.scatter(lats,
            max_temps,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Max Temperature "+ time.strftime("%x"))
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure.
plt.savefig("weather_data/Fig1.png")

# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. humidity.
plt.scatter(lats,
            humidity,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Humidity "+ time.strftime("%x"))
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig2.png")
# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. cloudiness.
plt.scatter(lats,
            cloudiness,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Cloudiness (%) "+ time.strftime("%x"))
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig3.png")
# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. wind speed.
plt.scatter(lats,
            wind_speed,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Wind Speed "+ time.strftime("%x"))
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig4.png")
# Show plot.
plt.show()

# %%
# Import linear regression from the SciPy stats module.
from scipy.stats import linregress

# %%
# Create an equal number of latitudes and temperatures.
lats = [42.5, 43.9, 8.1, 36.8, 79.9, 69.1, 25.7, 15.3, 12.7, 64.5]
temps = [80.5, 75.3, 90.9, 90.0, 40.4, 62.3, 85.4, 79.6, 72.5, 72.0]

# %%
# Perform linear regression.
(slope, intercept, r_value, p_value, std_err) = linregress(lats, temps)
# Get the equation of the line.
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(line_eq)
print(f"The p-value is: {p_value:.3f}")
# Out:
# y = -0.45x + 92.94
# The p-value is: 0.011

# %%
# Calculate the regression line "y values" from the slope and intercept.
regress_values = [(lat * slope + intercept) for lat in lats]
regress_values
# Out:
# [73.68973782871005,
#  73.05563705897195,
#  89.2704995994175,
#  76.27143381978658,
#  56.750188694278094,
#  61.64182320368626,
#  81.29894706556718,
#  86.00940992647874,
#  87.18702564170663,
#  63.72529716139714]

# %%
# Import Matplotlib.
import matplotlib.pyplot as plt
# Create a scatter plot of the x and y values.
plt.scatter(lats,temps)
# Plot the regression line with the x-values and the y coordinates based on the intercept and slope.
plt.plot(lats,regress_values,"r")
# Annotate the text for the line equation and add its coordinates.
plt.annotate(line_eq, (10,40), fontsize=15, color="red")
plt.xlabel('Latitude')
plt.ylabel('Temp')
plt.show()

# %%
# Import linregress
from scipy.stats import linregress


def plot_linear_regression(x_values, y_values, title, y_label, text_coordinates):

    # Perform linear regression.
    (slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)

# Calculate the regression line "y values" from the slope and intercept.
    regress_values = x_values * slope + intercept

# Get the equation of the line.
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Create a scatter plot of the x and y values.
    plt.scatter(x_values,y_values)
# Plot the regression line with the x-values and the y coordinates based on the intercept and slope.
    plt.plot(x_values,regress_values,"r")
# Annotate the text for the line equation and add its coordinates.
    plt.annotate(line_eq, (10,40), fontsize=15, color="red")
    plt.title(title)
    plt.xlabel('Latitude')
    plt.ylabel('Temp')
    plt.show()

# %%
# Import linregress
from scipy.stats import linregress

# Create a function to create perform linear regression on the weather data
# and plot a regression line and the equation with the data.
def plot_linear_regression(x_values, y_values, title, y_label, text_coordinates):

    # Run regression on hemisphere weather data.
    (slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)

    # Calculate the regression line "y values" from the slope and intercept.
    regress_values = x_values * slope + intercept
    # Get the equation of the line.
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    # Create a scatter plot and plot the regression line.
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r")
    # Annotate the text for the line equation.
    plt.annotate(line_eq, text_coordinates, fontsize=15, color="red")
    plt.title(title)
    plt.xlabel('Latitude')
    plt.ylabel(y_label)
    plt.show()

# %%
index13 = city_data_df.loc[13]
index13
# Out:
# City                   Winnemucca
# Lat                        40.973
# Lng                     -117.7357
# Max Temp                    53.65
# Humidity                       43
# Cloudiness                     20
# Wind Speed                  24.16
# Country                        US
# Date          2022-04-16 18:26:10
# Name: 13, dtype: object

# %%
city_data_df["Lat"] >= 0
# Out:
# 0      False
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 587     True
# 588     True
# 589     True
# 590     True
# 591    False
# Name: Lat, Length: 592, dtype: bool

# %%
city_data_df.loc[(city_data_df["Lat"] >= 0)]
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 1     Salekhard  66.5300   66.6019      8.67        90          96
# 2       College  64.8569 -147.8028     25.12        41          75
# 3       Inirida   3.8653  -67.9239     77.59        82         100
# 4     Jamestown  42.0970  -79.2353     48.06        56          75
# 6         Kapaa  22.0752 -159.3190     76.98        85          75
# ..          ...      ...       ...       ...       ...         ...
# 585     Makokou   0.5738   12.8642     76.59        80          99
# 587      Kovdor  67.5662   30.4758     34.16        80         100
# 588     Procida  40.7569   14.0144     67.98        50         100
# 589  Filadelfia  39.9523  -75.1638     77.02        33          75
# 590      Ankang  32.6800  109.0172     43.68        94         100
#
#      Wind Speed Country                 Date
# 1          5.75      RU  2022-04-16 18:26:07
# 2         10.36      US  2022-04-16 18:26:07
# 3          3.22      CO  2022-04-16 18:26:07
# 4         17.27      US  2022-04-16 18:21:47
# 6         14.97      US  2022-04-16 18:26:08
# ..          ...     ...                  ...
# 585        3.11      GA  2022-04-16 18:40:47
# 587       10.85      RU  2022-04-16 18:40:47
# 588       14.74      IT  2022-04-16 18:40:48
# 589       11.50      US  2022-04-16 18:36:27
# 590        1.36      CN  2022-04-16 18:39:11
#
# [415 rows x 9 columns]

# %%
city_data_df.loc[(city_data_df["Lat"] >= 0)].head()
# Out:
#         City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 1  Salekhard  66.5300   66.6019      8.67        90          96        5.75
# 2    College  64.8569 -147.8028     25.12        41          75       10.36
# 3    Inirida   3.8653  -67.9239     77.59        82         100        3.22
# 4  Jamestown  42.0970  -79.2353     48.06        56          75       17.27
# 6      Kapaa  22.0752 -159.3190     76.98        85          75       14.97
#
#   Country                 Date
# 1      RU  2022-04-16 18:26:07
# 2      US  2022-04-16 18:26:07
# 3      CO  2022-04-16 18:26:07
# 4      US  2022-04-16 18:21:47
# 6      US  2022-04-16 18:26:08

# %%
# Create Northern and Southern Hemisphere DataFrames.
northern_hemi_df = city_data_df.loc[(city_data_df["Lat"] >= 0)]
southern_hemi_df = city_data_df.loc[(city_data_df["Lat"] < 0)]

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \
                        for % Humidity', '% Humidity',(40,10))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \n for % Humidity', '% Humidity',(-50,15))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \n for % Cloudiness', '% Cloudiness',(-50,60))

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \n for Wind Speed', 'Wind Speed',(40,35))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \n for Wind Speed', 'Wind Speed',(-50,35))
