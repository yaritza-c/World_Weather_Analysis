# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 606

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
#print(url)

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in our list.
for i in range(len(cities)):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + cities[i]

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
       
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | dikson
# Processing Record 2 of Set 1 | atuona
# Processing Record 3 of Set 1 | popondetta
# Processing Record 4 of Set 1 | saint-philippe
# Processing Record 5 of Set 1 | talnakh
# Processing Record 6 of Set 1 | cape town
# Processing Record 7 of Set 1 | haibowan
# City not found. Skipping...
# Processing Record 8 of Set 1 | xichang
# Processing Record 9 of Set 1 | tuktoyaktuk
# Processing Record 10 of Set 1 | punta arenas
# Processing Record 11 of Set 1 | yaan
# Processing Record 12 of Set 1 | jumla
# Processing Record 13 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 14 of Set 1 | ushuaia
# Processing Record 15 of Set 1 | sao filipe
# Processing Record 16 of Set 1 | churapcha
# Processing Record 17 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 18 of Set 1 | te anau
# Processing Record 19 of Set 1 | san quintin
# Processing Record 20 of Set 1 | fairbanks
# Processing Record 21 of Set 1 | jamestown
# Processing Record 22 of Set 1 | lebu
# Processing Record 23 of Set 1 | hasaki
# Processing Record 24 of Set 1 | saint-pierre
# Processing Record 25 of Set 1 | grand centre
# City not found. Skipping...
# Processing Record 26 of Set 1 | karakendzha
# City not found. Skipping...
# Processing Record 27 of Set 1 | busselton
# Processing Record 28 of Set 1 | pasni
# Processing Record 29 of Set 1 | mount gambier
# Processing Record 30 of Set 1 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 31 of Set 1 | pimentel
# Processing Record 32 of Set 1 | bend
# Processing Record 33 of Set 1 | nam tha
# City not found. Skipping...
# Processing Record 34 of Set 1 | cayenne
# Processing Record 35 of Set 1 | cabo san lucas
# Processing Record 36 of Set 1 | hermanus
# Processing Record 37 of Set 1 | waddan
# Processing Record 38 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 39 of Set 1 | havelock
# Processing Record 40 of Set 1 | rikitea
# Processing Record 41 of Set 1 | upernavik
# Processing Record 42 of Set 1 | bethel
# Processing Record 43 of Set 1 | baker city
# Processing Record 44 of Set 1 | evensk
# Processing Record 45 of Set 1 | esperance
# Processing Record 46 of Set 1 | tuburan
# Processing Record 47 of Set 1 | stoyba
# City not found. Skipping...
# Processing Record 48 of Set 1 | hithadhoo
# Processing Record 49 of Set 1 | norman wells
# Processing Record 50 of Set 1 | guerrero negro
# Processing Record 1 of Set 2 | tezu
# Processing Record 2 of Set 2 | avarua
# Processing Record 3 of Set 2 | navolato
# Processing Record 4 of Set 2 | baboua
# City not found. Skipping...
# Processing Record 5 of Set 2 | mahebourg
# Processing Record 6 of Set 2 | nelson bay
# Processing Record 7 of Set 2 | bara
# Processing Record 8 of Set 2 | pangnirtung
# Processing Record 9 of Set 2 | mataura
# Processing Record 10 of Set 2 | okhotsk
# Processing Record 11 of Set 2 | chokurdakh
# Processing Record 12 of Set 2 | hami
# Processing Record 13 of Set 2 | amazar
# Processing Record 14 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 15 of Set 2 | umzimvubu
# City not found. Skipping...
# Processing Record 16 of Set 2 | asau
# Processing Record 17 of Set 2 | mildura
# Processing Record 18 of Set 2 | isangel
# Processing Record 19 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 20 of Set 2 | qaanaaq
# Processing Record 21 of Set 2 | itanhaem
# Processing Record 22 of Set 2 | qinggang
# Processing Record 23 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 24 of Set 2 | hilo
# Processing Record 25 of Set 2 | hobart
# Processing Record 26 of Set 2 | albany
# Processing Record 27 of Set 2 | sorkjosen
# Processing Record 28 of Set 2 | lavrentiya
# Processing Record 29 of Set 2 | port alfred
# Processing Record 30 of Set 2 | high level
# Processing Record 31 of Set 2 | lompoc
# Processing Record 32 of Set 2 | airai
# Processing Record 33 of Set 2 | eyl
# Processing Record 34 of Set 2 | chuy
# Processing Record 35 of Set 2 | byron bay
# Processing Record 36 of Set 2 | shipitsyno
# Processing Record 37 of Set 2 | new norfolk
# Processing Record 38 of Set 2 | butaritari
# Processing Record 39 of Set 2 | mutare
# Processing Record 40 of Set 2 | selma
# Processing Record 41 of Set 2 | carnarvon
# Processing Record 42 of Set 2 | canutama
# Processing Record 43 of Set 2 | provideniya
# Processing Record 44 of Set 2 | paamiut
# Processing Record 45 of Set 2 | puerto ayora
# Processing Record 46 of Set 2 | yellowknife
# Processing Record 47 of Set 2 | bluff
# Processing Record 48 of Set 2 | castro
# Processing Record 49 of Set 2 | vaini
# Processing Record 50 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 1 of Set 3 | barre
# Processing Record 2 of Set 3 | alpena
# Processing Record 3 of Set 3 | vysokogornyy
# Processing Record 4 of Set 3 | longyearbyen
# Processing Record 5 of Set 3 | san patricio
# Processing Record 6 of Set 3 | karauzyak
# City not found. Skipping...
# Processing Record 7 of Set 3 | vanimo
# Processing Record 8 of Set 3 | marawi
# Processing Record 9 of Set 3 | godre
# City not found. Skipping...
# Processing Record 10 of Set 3 | beyneu
# Processing Record 11 of Set 3 | port elizabeth
# Processing Record 12 of Set 3 | petropavlovsk-kamchatskiy
# Processing Record 13 of Set 3 | itarema
# Processing Record 14 of Set 3 | lagoa
# Processing Record 15 of Set 3 | bredasdorp
# Processing Record 16 of Set 3 | payakumbuh
# Processing Record 17 of Set 3 | saint-prosper
# Processing Record 18 of Set 3 | kiunga
# Processing Record 19 of Set 3 | svobodnyy
# Processing Record 20 of Set 3 | huarmey
# Processing Record 21 of Set 3 | sorong
# Processing Record 22 of Set 3 | barcelos
# Processing Record 23 of Set 3 | grand-santi
# Processing Record 24 of Set 3 | leningradskiy
# Processing Record 25 of Set 3 | mogadishu
# Processing Record 26 of Set 3 | beringovskiy
# Processing Record 27 of Set 3 | khatanga
# Processing Record 28 of Set 3 | barrow
# Processing Record 29 of Set 3 | ketchikan
# Processing Record 30 of Set 3 | kapaa
# Processing Record 31 of Set 3 | kazalinsk
# City not found. Skipping...
# Processing Record 32 of Set 3 | cockburn town
# Processing Record 33 of Set 3 | ponta do sol
# Processing Record 34 of Set 3 | jos
# Processing Record 35 of Set 3 | davis
# Processing Record 36 of Set 3 | wajima
# Processing Record 37 of Set 3 | tarnogskiy gorodok
# Processing Record 38 of Set 3 | fostoria
# Processing Record 39 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 40 of Set 3 | bengkulu
# Processing Record 41 of Set 3 | kaitangata
# Processing Record 42 of Set 3 | aleksandrov gay
# Processing Record 43 of Set 3 | aklavik
# Processing Record 44 of Set 3 | buchanan
# Processing Record 45 of Set 3 | praia da vitoria
# Processing Record 46 of Set 3 | torbay
# Processing Record 47 of Set 3 | mar del plata
# Processing Record 48 of Set 3 | bataipora
# Processing Record 49 of Set 3 | orlik
# Processing Record 50 of Set 3 | mugur-aksy
# Processing Record 1 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 2 of Set 4 | vardo
# Processing Record 3 of Set 4 | gulbarga
# Processing Record 4 of Set 4 | bambanglipuro
# Processing Record 5 of Set 4 | sakhon nakhon
# Processing Record 6 of Set 4 | inhambane
# Processing Record 7 of Set 4 | henties bay
# Processing Record 8 of Set 4 | bud
# Processing Record 9 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 10 of Set 4 | polovinnoye
# Processing Record 11 of Set 4 | itoman
# Processing Record 12 of Set 4 | turukhansk
# Processing Record 13 of Set 4 | ahar
# Processing Record 14 of Set 4 | namatanai
# Processing Record 15 of Set 4 | amahai
# Processing Record 16 of Set 4 | luau
# Processing Record 17 of Set 4 | pisco
# Processing Record 18 of Set 4 | lolua
# City not found. Skipping...
# Processing Record 19 of Set 4 | san cristobal
# Processing Record 20 of Set 4 | kavieng
# Processing Record 21 of Set 4 | georgetown
# Processing Record 22 of Set 4 | ulaanbaatar
# Processing Record 23 of Set 4 | richards bay
# Processing Record 24 of Set 4 | jalor
# Processing Record 25 of Set 4 | aksu
# Processing Record 26 of Set 4 | ribeira grande
# Processing Record 27 of Set 4 | russell
# Processing Record 28 of Set 4 | nantucket
# Processing Record 29 of Set 4 | ereymentau
# Processing Record 30 of Set 4 | gizo
# Processing Record 31 of Set 4 | taoudenni
# Processing Record 32 of Set 4 | bulawayo
# Processing Record 33 of Set 4 | batticaloa
# Processing Record 34 of Set 4 | cherskiy
# Processing Record 35 of Set 4 | tual
# Processing Record 36 of Set 4 | karratha
# Processing Record 37 of Set 4 | suntar
# Processing Record 38 of Set 4 | arraial do cabo
# Processing Record 39 of Set 4 | rawson
# Processing Record 40 of Set 4 | korla
# Processing Record 41 of Set 4 | saldanha
# Processing Record 42 of Set 4 | show low
# Processing Record 43 of Set 4 | raudeberg
# Processing Record 44 of Set 4 | betsiamites
# Processing Record 45 of Set 4 | burns lake
# Processing Record 46 of Set 4 | kodiak
# Processing Record 47 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 48 of Set 4 | naantali
# Processing Record 49 of Set 4 | buala
# Processing Record 50 of Set 4 | pyay
# Processing Record 1 of Set 5 | cabedelo
# Processing Record 2 of Set 5 | tanshui
# City not found. Skipping...
# Processing Record 3 of Set 5 | santa cruz
# Processing Record 4 of Set 5 | wukari
# Processing Record 5 of Set 5 | pevek
# Processing Record 6 of Set 5 | am timan
# Processing Record 7 of Set 5 | baffa
# Processing Record 8 of Set 5 | vilhena
# Processing Record 9 of Set 5 | gat
# Processing Record 10 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 11 of Set 5 | farah
# Processing Record 12 of Set 5 | orje
# Processing Record 13 of Set 5 | tsienyane
# City not found. Skipping...
# Processing Record 14 of Set 5 | deputatskiy
# Processing Record 15 of Set 5 | curup
# Processing Record 16 of Set 5 | thompson
# Processing Record 17 of Set 5 | eldikan
# City not found. Skipping...
# Processing Record 18 of Set 5 | tarrafal
# Processing Record 19 of Set 5 | lodja
# Processing Record 20 of Set 5 | nikolskoye
# Processing Record 21 of Set 5 | los algarrobos
# Processing Record 22 of Set 5 | cidreira
# Processing Record 23 of Set 5 | tura
# Processing Record 24 of Set 5 | nyzhni sirohozy
# Processing Record 25 of Set 5 | saskylakh
# Processing Record 26 of Set 5 | husavik
# Processing Record 27 of Set 5 | znamenskoye
# Processing Record 28 of Set 5 | ancud
# Processing Record 29 of Set 5 | sturgis
# Processing Record 30 of Set 5 | alofi
# Processing Record 31 of Set 5 | aizkraukle
# Processing Record 32 of Set 5 | burica
# City not found. Skipping...
# Processing Record 33 of Set 5 | shimoda
# Processing Record 34 of Set 5 | moose factory
# Processing Record 35 of Set 5 | kamenka
# Processing Record 36 of Set 5 | saint-augustin
# Processing Record 37 of Set 5 | gazli
# Processing Record 38 of Set 5 | iberia
# Processing Record 39 of Set 5 | samarai
# Processing Record 40 of Set 5 | buedu
# Processing Record 41 of Set 5 | ferrol
# Processing Record 42 of Set 5 | komsomolskiy
# Processing Record 43 of Set 5 | ambikapur
# Processing Record 44 of Set 5 | santiago del estero
# Processing Record 45 of Set 5 | shengjin
# Processing Record 46 of Set 5 | borama
# City not found. Skipping...
# Processing Record 47 of Set 5 | codrington
# Processing Record 48 of Set 5 | muros
# Processing Record 49 of Set 5 | qaqortoq
# Processing Record 50 of Set 5 | zinder
# Processing Record 1 of Set 6 | yuli
# Processing Record 2 of Set 6 | rocha
# Processing Record 3 of Set 6 | mackenzie
# Processing Record 4 of Set 6 | tarko-sale
# Processing Record 5 of Set 6 | shushtar
# Processing Record 6 of Set 6 | borba
# Processing Record 7 of Set 6 | oriximina
# Processing Record 8 of Set 6 | otsuki
# Processing Record 9 of Set 6 | moranbah
# Processing Record 10 of Set 6 | vyazemskiy
# Processing Record 11 of Set 6 | santa maria
# Processing Record 12 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 13 of Set 6 | yashiro
# Processing Record 14 of Set 6 | champasak
# Processing Record 15 of Set 6 | sturgeon bay
# Processing Record 16 of Set 6 | sangar
# Processing Record 17 of Set 6 | rio grande
# Processing Record 18 of Set 6 | svetlogorsk
# Processing Record 19 of Set 6 | auki
# Processing Record 20 of Set 6 | storforshei
# Processing Record 21 of Set 6 | zemio
# Processing Record 22 of Set 6 | vestbygda
# City not found. Skipping...
# Processing Record 23 of Set 6 | la ronge
# Processing Record 24 of Set 6 | erzin
# Processing Record 25 of Set 6 | kodinsk
# Processing Record 26 of Set 6 | limoges
# Processing Record 27 of Set 6 | opuwo
# Processing Record 28 of Set 6 | mantua
# Processing Record 29 of Set 6 | thatcham
# Processing Record 30 of Set 6 | falealupo
# City not found. Skipping...
# Processing Record 31 of Set 6 | rehoboth
# Processing Record 32 of Set 6 | souillac
# Processing Record 33 of Set 6 | rio pardo de minas
# Processing Record 34 of Set 6 | goryachiy klyuch
# Processing Record 35 of Set 6 | lesozavodsk
# Processing Record 36 of Set 6 | alice springs
# Processing Record 37 of Set 6 | gushikawa
# Processing Record 38 of Set 6 | flinders
# Processing Record 39 of Set 6 | asyut
# Processing Record 40 of Set 6 | sao joao da barra
# Processing Record 41 of Set 6 | vila velha
# Processing Record 42 of Set 6 | udachnyy
# Processing Record 43 of Set 6 | tiksi
# Processing Record 44 of Set 6 | farafangana
# Processing Record 45 of Set 6 | vao
# Processing Record 46 of Set 6 | cacule
# Processing Record 47 of Set 6 | dezful
# Processing Record 48 of Set 6 | wanning
# Processing Record 49 of Set 6 | mehamn
# Processing Record 50 of Set 6 | lingao
# Processing Record 1 of Set 7 | arklow
# Processing Record 2 of Set 7 | hualmay
# Processing Record 3 of Set 7 | mitsamiouli
# Processing Record 4 of Set 7 | nome
# Processing Record 5 of Set 7 | kovdor
# Processing Record 6 of Set 7 | narsaq
# Processing Record 7 of Set 7 | matara
# Processing Record 8 of Set 7 | manokwari
# Processing Record 9 of Set 7 | kulhudhuffushi
# Processing Record 10 of Set 7 | makinsk
# Processing Record 11 of Set 7 | ituni
# City not found. Skipping...
# Processing Record 12 of Set 7 | biak
# Processing Record 13 of Set 7 | sofiysk
# City not found. Skipping...
# Processing Record 14 of Set 7 | mount isa
# Processing Record 15 of Set 7 | fortuna
# Processing Record 16 of Set 7 | yizheng
# Processing Record 17 of Set 7 | troyes
# Processing Record 18 of Set 7 | kalengwa
# Processing Record 19 of Set 7 | victoria
# Processing Record 20 of Set 7 | faya
# Processing Record 21 of Set 7 | riyadh
# Processing Record 22 of Set 7 | moron
# Processing Record 23 of Set 7 | kavaratti
# Processing Record 24 of Set 7 | saint george
# Processing Record 25 of Set 7 | sola
# Processing Record 26 of Set 7 | san jose
# Processing Record 27 of Set 7 | honiara
# Processing Record 28 of Set 7 | padang
# Processing Record 29 of Set 7 | uruzgan
# Processing Record 30 of Set 7 | saint anthony
# Processing Record 31 of Set 7 | sitka
# Processing Record 32 of Set 7 | bambous virieux
# Processing Record 33 of Set 7 | igarka
# Processing Record 34 of Set 7 | kidal
# Processing Record 35 of Set 7 | tasiilaq
# Processing Record 36 of Set 7 | lampang
# Processing Record 37 of Set 7 | meulaboh
# Processing Record 38 of Set 7 | catuday
# Processing Record 39 of Set 7 | oistins
# Processing Record 40 of Set 7 | luderitz
# Processing Record 41 of Set 7 | tapaua
# City not found. Skipping...
# Processing Record 42 of Set 7 | lorengau
# Processing Record 43 of Set 7 | awjilah
# Processing Record 44 of Set 7 | coihaique
# Processing Record 45 of Set 7 | venado tuerto
# Processing Record 46 of Set 7 | caxito
# Processing Record 47 of Set 7 | fianarantsoa
# Processing Record 48 of Set 7 | nouadhibou
# Processing Record 49 of Set 7 | cascais
# Processing Record 50 of Set 7 | oboyan
# Processing Record 1 of Set 8 | ust-tsilma
# Processing Record 2 of Set 8 | starokozache
# Processing Record 3 of Set 8 | siparia
# Processing Record 4 of Set 8 | abalak
# Processing Record 5 of Set 8 | sembe
# Processing Record 6 of Set 8 | redmond
# Processing Record 7 of Set 8 | aasiaat
# Processing Record 8 of Set 8 | iki-burul
# Processing Record 9 of Set 8 | vaitape
# Processing Record 10 of Set 8 | zaozerne
# Processing Record 11 of Set 8 | srednekolymsk
# Processing Record 12 of Set 8 | maragogi
# Processing Record 13 of Set 8 | ayan
# Processing Record 14 of Set 8 | kaputa
# Processing Record 15 of Set 8 | haines junction
# Processing Record 16 of Set 8 | san pedro de macoris
# Processing Record 17 of Set 8 | hambantota
# Processing Record 18 of Set 8 | saryshagan
# City not found. Skipping...
# Processing Record 19 of Set 8 | port blair
# Processing Record 20 of Set 8 | iqaluit
# Processing Record 21 of Set 8 | trinidad
# Processing Record 22 of Set 8 | ben tre
# Processing Record 23 of Set 8 | east london
# Processing Record 24 of Set 8 | port hardy
# Processing Record 25 of Set 8 | ginda
# Processing Record 26 of Set 8 | chimore
# Processing Record 27 of Set 8 | clyde river
# Processing Record 28 of Set 8 | arman
# Processing Record 29 of Set 8 | miraflores
# Processing Record 30 of Set 8 | saint-joseph
# Processing Record 31 of Set 8 | margate
# Processing Record 32 of Set 8 | adrar
# Processing Record 33 of Set 8 | laguna
# Processing Record 34 of Set 8 | kahului
# Processing Record 35 of Set 8 | sinkat
# City not found. Skipping...
# Processing Record 36 of Set 8 | evanston
# Processing Record 37 of Set 8 | filadelfia
# Processing Record 38 of Set 8 | kieta
# Processing Record 39 of Set 8 | ust-ilimsk
# Processing Record 40 of Set 8 | kaniama
# Processing Record 41 of Set 8 | awbari
# Processing Record 42 of Set 8 | inzhavino
# Processing Record 43 of Set 8 | okha
# Processing Record 44 of Set 8 | tigzirt
# Processing Record 45 of Set 8 | nasirabad
# Processing Record 46 of Set 8 | zaraza
# Processing Record 47 of Set 8 | atar
# Processing Record 48 of Set 8 | benguela
# Processing Record 49 of Set 8 | walvis bay
# Processing Record 50 of Set 8 | anda
# Processing Record 1 of Set 9 | matay
# Processing Record 2 of Set 9 | faanui
# Processing Record 3 of Set 9 | krasnyye baki
# Processing Record 4 of Set 9 | bahia de caraquez
# Processing Record 5 of Set 9 | mackay
# Processing Record 6 of Set 9 | belaya gora
# Processing Record 7 of Set 9 | ginir
# Processing Record 8 of Set 9 | harper
# Processing Record 9 of Set 9 | ostrovnoy
# Processing Record 10 of Set 9 | prijepolje
# Processing Record 11 of Set 9 | flateby
# Processing Record 12 of Set 9 | pitimbu
# Processing Record 13 of Set 9 | mattawa
# Processing Record 14 of Set 9 | ornskoldsvik
# Processing Record 15 of Set 9 | birao
# Processing Record 16 of Set 9 | sorada
# Processing Record 17 of Set 9 | arbagar
# Processing Record 18 of Set 9 | shimanovsk
# Processing Record 19 of Set 9 | parnarama
# Processing Record 20 of Set 9 | shu
# Processing Record 21 of Set 9 | grand river south east
# City not found. Skipping...
# Processing Record 22 of Set 9 | kenora
# Processing Record 23 of Set 9 | kununurra
# Processing Record 24 of Set 9 | ola
# Processing Record 25 of Set 9 | tilichiki
# Processing Record 26 of Set 9 | acajutla
# Processing Record 27 of Set 9 | hohhot
# Processing Record 28 of Set 9 | maniitsoq
# Processing Record 29 of Set 9 | taburi
# City not found. Skipping...
# Processing Record 30 of Set 9 | passo de camaragibe
# Processing Record 31 of Set 9 | kasongo-lunda
# Processing Record 32 of Set 9 | maku
# Processing Record 33 of Set 9 | viedma
# Processing Record 34 of Set 9 | sterling
# Processing Record 35 of Set 9 | finschhafen
# Processing Record 36 of Set 9 | shahr-e babak
# Processing Record 37 of Set 9 | abernethy
# Processing Record 38 of Set 9 | coruripe
# Processing Record 39 of Set 9 | luanda
# Processing Record 40 of Set 9 | nosy varika
# Processing Record 41 of Set 9 | dingle
# Processing Record 42 of Set 9 | acquaviva
# Processing Record 43 of Set 9 | tucupita
# Processing Record 44 of Set 9 | warwick
# Processing Record 45 of Set 9 | kegayli
# City not found. Skipping...
# Processing Record 46 of Set 9 | jadu
# Processing Record 47 of Set 9 | nguiu
# City not found. Skipping...
# Processing Record 48 of Set 9 | barawe
# City not found. Skipping...
# Processing Record 49 of Set 9 | calatayud
# Processing Record 50 of Set 9 | uige
# Processing Record 1 of Set 10 | yaring
# Processing Record 2 of Set 10 | fonte boa
# Processing Record 3 of Set 10 | altay
# Processing Record 4 of Set 10 | constitucion
# Processing Record 5 of Set 10 | lazarev
# Processing Record 6 of Set 10 | mega
# Processing Record 7 of Set 10 | akropong
# Processing Record 8 of Set 10 | necochea
# Processing Record 9 of Set 10 | nhulunbuy
# Processing Record 10 of Set 10 | yulara
# Processing Record 11 of Set 10 | semey
# Processing Record 12 of Set 10 | parit buntar
# Processing Record 13 of Set 10 | hendersonville
# Processing Record 14 of Set 10 | lock haven
# Processing Record 15 of Set 10 | shellbrook
# Processing Record 16 of Set 10 | safakulevo
# Processing Record 17 of Set 10 | tsiroanomandidy
# Processing Record 18 of Set 10 | yuza
# Processing Record 19 of Set 10 | gimli
# Processing Record 20 of Set 10 | benghazi
# Processing Record 21 of Set 10 | port macquarie
# Processing Record 22 of Set 10 | terenos
# Processing Record 23 of Set 10 | champerico
# Processing Record 24 of Set 10 | hay river
# Processing Record 25 of Set 10 | kholtoson
# Processing Record 26 of Set 10 | norton
# Processing Record 27 of Set 10 | ardakan
# Processing Record 28 of Set 10 | anloga
# Processing Record 29 of Set 10 | pak phanang
# Processing Record 30 of Set 10 | linqing
# Processing Record 31 of Set 10 | veraval
# Processing Record 32 of Set 10 | wahran
# City not found. Skipping...
# Processing Record 33 of Set 10 | nabire
# Processing Record 34 of Set 10 | olafsvik
# Processing Record 35 of Set 10 | mosquera
# Processing Record 36 of Set 10 | avera
# Processing Record 37 of Set 10 | ilulissat
# Processing Record 38 of Set 10 | okulovka
# Processing Record 39 of Set 10 | machali
# Processing Record 40 of Set 10 | poum
# Processing Record 41 of Set 10 | bon air
# Processing Record 42 of Set 10 | bridlington
# Processing Record 43 of Set 10 | port hedland
# Processing Record 44 of Set 10 | luis correia
# Processing Record 45 of Set 10 | mareeba
# Processing Record 46 of Set 10 | satitoa
# City not found. Skipping...
# Processing Record 47 of Set 10 | colombo
# Processing Record 48 of Set 10 | madinat sittah uktubar
# Processing Record 49 of Set 10 | russellville
# Processing Record 50 of Set 10 | neuquen
# Processing Record 1 of Set 11 | severo-kurilsk
# Processing Record 2 of Set 11 | tsihombe
# City not found. Skipping...
# Processing Record 3 of Set 11 | wahiawa
# Processing Record 4 of Set 11 | tessalit
# Processing Record 5 of Set 11 | bedele
# Processing Record 6 of Set 11 | kuala perlis
# Processing Record 7 of Set 11 | chikwawa
# Processing Record 8 of Set 11 | ngukurr
# City not found. Skipping...
# Processing Record 9 of Set 11 | akyab
# Processing Record 10 of Set 11 | hailar
# Processing Record 11 of Set 11 | tunceli
# Processing Record 12 of Set 11 | egvekinot
# Processing Record 13 of Set 11 | katsuura
# Processing Record 14 of Set 11 | umm kaddadah
# Processing Record 15 of Set 11 | koumac
# Processing Record 16 of Set 11 | uyuni
# Processing Record 17 of Set 11 | toliary
# City not found. Skipping...
# Processing Record 18 of Set 11 | kinshasa
# Processing Record 19 of Set 11 | ixtapa
# Processing Record 20 of Set 11 | zeya
# Processing Record 21 of Set 11 | porto santo
# Processing Record 22 of Set 11 | ilo
# Processing Record 23 of Set 11 | chapais
# Processing Record 24 of Set 11 | kruisfontein
# Processing Record 25 of Set 11 | umarizal
# Processing Record 26 of Set 11 | goderich
# Processing Record 27 of Set 11 | carroll
# Processing Record 28 of Set 11 | san martin
# Processing Record 29 of Set 11 | touros
# Processing Record 30 of Set 11 | safranbolu
# Processing Record 31 of Set 11 | wewak
# Processing Record 32 of Set 11 | tahta
# Processing Record 33 of Set 11 | komatipoort
# Processing Record 34 of Set 11 | kemin
# Processing Record 35 of Set 11 | santiago de chuco
# Processing Record 36 of Set 11 | luocheng
# Processing Record 37 of Set 11 | balkanabat
# Processing Record 38 of Set 11 | tiznit
# Processing Record 39 of Set 11 | obo
# Processing Record 40 of Set 11 | changqing
# Processing Record 41 of Set 11 | la gaulette
# City not found. Skipping...
# Processing Record 42 of Set 11 | japura
# Processing Record 43 of Set 11 | san policarpo
# Processing Record 44 of Set 11 | bay city
# Processing Record 45 of Set 11 | tomatlan
# Processing Record 46 of Set 11 | muli
# Processing Record 47 of Set 11 | makakilo city
# Processing Record 48 of Set 11 | iseyin
# Processing Record 49 of Set 11 | baruun-urt
# Processing Record 50 of Set 11 | svetlaya
# Processing Record 1 of Set 12 | jacqueville
# Processing Record 2 of Set 12 | mulanje
# Processing Record 3 of Set 12 | gurupa
# Processing Record 4 of Set 12 | fort nelson
# Processing Record 5 of Set 12 | arlit
# Processing Record 6 of Set 12 | aripuana
# Processing Record 7 of Set 12 | reinosa
# Processing Record 8 of Set 12 | makung
# City not found. Skipping...
# Processing Record 9 of Set 12 | copiapo
# Processing Record 10 of Set 12 | spencer
# Processing Record 11 of Set 12 | tabou
# Processing Record 12 of Set 12 | oshakati
# Processing Record 13 of Set 12 | juneau
# Processing Record 14 of Set 12 | nyrob
# Processing Record 15 of Set 12 | kapustin yar
# Processing Record 16 of Set 12 | labuhan
# Processing Record 17 of Set 12 | viloco
# Processing Record 18 of Set 12 | halalo
# City not found. Skipping...
# Processing Record 19 of Set 12 | berlevag
# Processing Record 20 of Set 12 | broken hill
# Processing Record 21 of Set 12 | severo-yeniseyskiy
# Processing Record 22 of Set 12 | sinnamary
# Processing Record 23 of Set 12 | noumea
# Processing Record 24 of Set 12 | kamenskoye
# City not found. Skipping...
# Processing Record 25 of Set 12 | chincholi
# Processing Record 26 of Set 12 | carballo
# Processing Record 27 of Set 12 | gangakher
# Processing Record 28 of Set 12 | road town
# Processing Record 29 of Set 12 | silyanah
# City not found. Skipping...
# Processing Record 30 of Set 12 | abis
# Processing Record 31 of Set 12 | palu
# Processing Record 32 of Set 12 | bubaque
# Processing Record 33 of Set 12 | galveston
# Processing Record 34 of Set 12 | babanusah
# City not found. Skipping...
# Processing Record 35 of Set 12 | southlake
# Processing Record 36 of Set 12 | mrirt
# City not found. Skipping...
# Processing Record 37 of Set 12 | fevralsk
# City not found. Skipping...
# Processing Record 38 of Set 12 | tevaitoa
# Processing Record 39 of Set 12 | urdzhar
# City not found. Skipping...
# Processing Record 40 of Set 12 | sherbakul
# Processing Record 41 of Set 12 | daru
# Processing Record 42 of Set 12 | tuatapere
# Processing Record 43 of Set 12 | nuevo progreso
# Processing Record 44 of Set 12 | dalby
# Processing Record 45 of Set 12 | xochihuehuetlan
# Processing Record 46 of Set 12 | vitimskiy
# City not found. Skipping...
# Processing Record 47 of Set 12 | chara
# Processing Record 48 of Set 12 | san joaquin
# Processing Record 49 of Set 12 | high prairie
# Processing Record 50 of Set 12 | aswan
# Processing Record 1 of Set 13 | kjollefjord
# Processing Record 2 of Set 13 | moorhead
# Processing Record 3 of Set 13 | morondava
# Processing Record 4 of Set 13 | cap malheureux
# Processing Record 5 of Set 13 | berdigestyakh
# Processing Record 6 of Set 13 | warqla
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0            Dikson  73.5069   80.5464      8.62        89         100
# 1            Atuona  -9.8000 -139.0333     78.78        80          73
# 2        Popondetta  -8.7537  148.2534     87.06        65          99
# 3    Saint-Philippe -21.3585   55.7679     79.21        81          25
# 4           Talnakh  69.4865   88.3972     15.15        93          96
# ..              ...      ...       ...       ...       ...         ...
# 543     Kjollefjord  70.9457   27.3465     39.25        92         100
# 544        Moorhead  46.8739  -96.7676     24.82        73           0
# 545       Morondava -20.2833   44.2833     80.29        87           2
# 546  Cap Malheureux -19.9842   57.6142     81.46        81          57
# 547   Berdigestyakh  62.0989  126.6992     30.15        77          94
#
#      Wind Speed Country                 Date
# 0         15.21      RU  2022-04-17 04:38:03
# 1         16.60      PF  2022-04-17 04:38:04
# 2          5.10      PG  2022-04-17 04:38:04
# 3         11.01      RE  2022-04-17 04:38:04
# 4         17.22      RU  2022-04-17 04:38:04
# ..          ...     ...                  ...
# 543       24.14      NO  2022-04-17 04:52:38
# 544        5.75      US  2022-04-17 04:50:14
# 545        7.23      MG  2022-04-17 04:52:38
# 546       11.99      MU  2022-04-17 04:52:38
# 547        5.53      RU  2022-04-17 04:52:38
#
# [548 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
